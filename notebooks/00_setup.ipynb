# %% [markdown]
# Lets start with setyup
#
# 1) connect with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
BASE = "/content/drive/MyDrive/stress-project"
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Install pandas and packages

# %%
# !pip install pandas==2.2.3 --quiet
# !pip install wfdb==4.3.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 92.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# 3) Install other required packages

# %%
# !pip install -q numpy scipy scikit-learn matplotlib seaborn plotly pywavelets neurokit2 wfdb torch torchvision torchaudio einops tqdm shap imbalanced-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.4/708.4 kB 13.5 MB/s eta 0:00:00

# %%
import numpy as np, torch, random
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %% [markdown]
# 4) Create a project in drive and create the all other required folders in Drive

# %%
import os
folders = ["data_raw/wesad","data_raw/physionet_exam","data_raw/hrv_sleep",
           "data_processed","notebooks","src","models","reports/figures","dashboard"]
for f in folders:
    os.makedirs(f"{BASE}/{f}", exist_ok=True)
print("Folders ready ✅")
# Out:
# Folders ready ✅

# %% [markdown]
# 5) Create a Readme file

# %%
with open(f"{BASE}/README.md", "w") as f:
    f.write("# Stress Prediction from Wearable Sensor Data\n")

# %%
import os

# List folders inside physionet_exam (should show Subject_01 etc.)
print("Subject folders:", os.listdir('/content/drive/MyDrive/stress-project/data_raw/physionet_exam'))

# List files inside Subject_01
print("Files in Subject_01:", os.listdir('/content/drive/MyDrive/stress-project/data_raw/physionet_exam/Subject_01'))
# Out:
# Subject folders: ['Subject_01', 'Subject_02', 'Subject_03', 'Subject_04', 'Subject_05']
# Files in Subject_01: ['EDA.csv', 'HR.csv', 'IBI.csv', 'info.txt', 'TEMP.csv', 'tags.csv', 'ACC.csv', 'BVP.csv', 'tags.gsheet']

# %% [markdown]
# 6) Examine one subject and see how the data is ?

# %%
import pandas as pd
sd = '/content/drive/MyDrive/stress-project/data_raw/physionet_exam/Subject_01'
eda = pd.read_csv(f"{sd}/EDA.csv")
hr = pd.read_csv(f"{sd}/HR.csv")
acc = pd.read_csv(f"{sd}/ACC.csv")
temp = pd.read_csv(f"{sd}/TEMP.csv")
print(eda.head())
print(hr.head())
print(acc.head())
print(temp.head())
# Out:
#    1544027337.000000
# 0           4.000000
# 1           0.000000
# 2           0.005125
# 3           0.020501
# 4           0.021783
#    1544027347.000000
# 0               1.00
# 1             116.00
# 2              82.50
# 3              96.33
# 4              86.25
#    1544027337.000000   1544027337.000000   1544027337.000000.1
# 0               32.0                32.0                  32.0
# 1               -3.0                65.0                   6.0
# 2               -3.0                65.0                   6.0
# 3               -3.0                65.0                   6.0
# 4               -3.0                65.0                   6.0
#    1544027337.000000
# 0               4.00
# 1              21.89
# 2              21.89
# 3              21.89
# 4              21.89
